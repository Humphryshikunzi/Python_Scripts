# %%
import requests
import json

# %%
# use get to get current lon and lat of international space station
response = requests.get("http://api.open-notify.org/iss-now.json")
print(response.status_code)
# Out:
# 200

# %%
# check the encoding, this can be used to change if needed e.g from utf-8 to 'ISO-8859-1'
print(response.encoding)
# Out:
# None

# %%
print(response.content)
# Out:
# b'{"iss_position": {"latitude": "-49.3755", "longitude": "-141.7420"}, "message": "success", "timestamp": 1592123645}'

# %%
# view headers
print(response.headers)

print('Content type {}'.format(response.headers['Content-Type']))
# Out:
# {'Server': 'nginx/1.10.3', 'Date': 'Sun, 14 Jun 2020 14:13:53 GMT', 'Content-Type': 'application/json', 'Content-Length': '112', 'Connection': 'keep-alive', 'access-control-allow-origin': '*'}
# Content type application/json

# %%
# test status codes by supplying an endpoint that does not exist
response = requests.get("http://api.open-notify.org/iss-pass")
print(response.status_code)
# Out:
# 404

# %%
# making a request with params
# lets make a request with params of Nairobi, to determine when the ISS will pass by Nairobi

parameters = {"lat": -1.28, "lon": 36.81}

response = requests.get("http://api.open-notify.org/iss-pass.json", params = parameters)
# Print the content of the response (the data the server returned)
print(response.content)
# Out:
# b'{\n  "message": "success", \n  "request": {\n    "altitude": 100, \n    "datetime": 1592124260, \n    "latitude": -1.28, \n    "longitude": 36.81, \n    "passes": 5\n  }, \n  "response": [\n    {\n      "duration": 650, \n      "risetime": 1592150021\n    }, \n    {\n      "duration": 337, \n      "risetime": 1592155978\n    }, \n    {\n      "duration": 646, \n      "risetime": 1592191757\n    }, \n    {\n      "duration": 371, \n      "risetime": 1592197692\n    }, \n    {\n      "duration": 619, \n      "risetime": 1592233568\n    }\n  ]\n}\n'

# %%
# This gets the same data as the command above response = 
requests.get("http://api.open-notify.org/iss-pass.json?lat=-1.28&lon=36.81")
print(response.content)
# Out:
# b'{\n  "message": "success", \n  "request": {\n    "altitude": 100, \n    "datetime": 1592124260, \n    "latitude": -1.28, \n    "longitude": 36.81, \n    "passes": 5\n  }, \n  "response": [\n    {\n      "duration": 650, \n      "risetime": 1592150021\n    }, \n    {\n      "duration": 337, \n      "risetime": 1592155978\n    }, \n    {\n      "duration": 646, \n      "risetime": 1592191757\n    }, \n    {\n      "duration": 371, \n      "risetime": 1592197692\n    }, \n    {\n      "duration": 619, \n      "risetime": 1592233568\n    }\n  ]\n}\n'

# %%
# convert the response from bytes to string
str_content = response.content.decode("utf-8")
print('The type of the string is {}'.format(type(str_content)))
print(str_content)
# Out:
# The type of the string is <class 'str'>
# {
#   "message": "success",
#   "request": {
#     "altitude": 100,
#     "datetime": 1592124260,
#     "latitude": -1.28,
#     "longitude": 36.81,
#     "passes": 5
#   },
#   "response": [
#     {
#       "duration": 650,
#       "risetime": 1592150021
#     },
#     {
#       "duration": 337,
#       "risetime": 1592155978
#     },
#     {
#       "duration": 646,
#       "risetime": 1592191757
#     },
#     {
#       "duration": 371,
#       "risetime": 1592197692
#     },
#     {
#       "duration": 619,
#       "risetime": 1592233568
#     }
#   ]
# }

# %%
# we need to work with this data in json format, we can use loads and dumps method of json to do this
print(type(str_content))
# Out:
# <class 'str'>

# %%
import json

# %%
# convert the data to dictionary
print(type(json.loads(str_content)))
dict_data = json.loads(str_content)
dict_data
# Out:
# <class 'dict'>
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1592124260,
#   'latitude': -1.28,
#   'longitude': 36.81,
#   'passes': 5},
#  'response': [{'duration': 650, 'risetime': 1592150021},
#   {'duration': 337, 'risetime': 1592155978},
#   {'duration': 646, 'risetime': 1592191757},
#   {'duration': 371, 'risetime': 1592197692},
#   {'duration': 619, 'risetime': 1592233568}]}

# %%
# convert the data back to string, so as to send it perhaps
print(type(json.dumps(dict_data)))
json.dumps(dict_data)
# Out:
# <class 'str'>
# '{"message": "success", "request": {"altitude": 100, "datetime": 1592124260, "latitude": -1.28, "longitude": 36.81, "passes": 5}, "response": [{"duration": 650, "risetime": 1592150021}, {"duration": 337, "risetime": 1592155978}, {"duration": 646, "risetime": 1592191757}, {"duration": 371, "risetime": 1592197692}, {"duration": 619, "risetime": 1592233568}]}'

# %%
 # Make the same request we did earlier, but with the coordinates of San Francisco instead.
response = requests.get("http://api.open-notify.org/iss-pass.json", params=parameters)

# Get the response data as a python object. Verify that it's a dictionary.
data = response.json()
print(type(data))
print(data)
# Out:
# <class 'dict'>
# {'message': 'success', 'request': {'altitude': 100, 'datetime': 1592124260, 'latitude': -1.28, 'longitude': 36.81, 'passes': 5}, 'response': [{'duration': 650, 'risetime': 1592150021}, {'duration': 337, 'risetime': 1592155978}, {'duration': 646, 'risetime': 1592191757}, {'duration': 371, 'risetime': 1592197692}, {'duration': 619, 'risetime': 1592233568}]}

# %%
#checking the content-type of the response
# Headers is a dictionary
print(response.headers)
# Get the content-type from the dictionary.
print(response.headers["content-type"])
# Out:
# {'Server': 'nginx/1.10.3', 'Date': 'Sun, 14 Jun 2020 08:58:10 GMT', 'Content-Type': 'application/json', 'Content-Length': '519', 'Connection': 'keep-alive', 'Via': '1.1 vegur'}
# application/json

# %%
# Another endpoint to find the Number of astronouts in space station

# Get the response from the API endpoint.
response = requests.get("http://api.open-notify.org/astros.json")
data = response.json()
# 9 people are currently in space.
print(data["number"])
print(data)
# Out:
# 5
# {'message': 'success', 'number': 5, 'people': [{'craft': 'ISS', 'name': 'Chris Cassidy'}, {'craft': 'ISS', 'name': 'Anatoly Ivanishin'}, {'craft': 'ISS', 'name': 'Ivan Vagner'}, {'craft': 'ISS', 'name': 'Doug Hurley'}, {'craft': 'ISS', 'name': 'Bob Behnken'}]}

# %% [markdown]
# ## Requets Doc Itself https://2.python-requests.org/en/latest/

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
# know all that requests can do
print(dir(r))
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']

# %%
print('The status code for r is {}'.format(r))
print('The contengt for r is\n {}'.format(r.content))
# Out:
# The status code for r is <Response [200]>
# The contengt for r is
#  b'[{"id":"12625854335","type":"PushEvent","actor":{"id":43147301,"login":"SHyeon614","display_login":"SHyeon614","gravatar_id":"","url":"https://api.github.com/users/SHyeon614","avatar_url":"https://avatars.githubusercontent.com/u/43147301?"},"repo":{"id":262723077,"name":"SHyeon614/Golang-practice","url":"https://api.github.com/repos/SHyeon614/Golang-practice"},"payload":{"push_id":5226766242,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"3f1aea3062937f26134bae46688157292ce6ec41","before":"993edcee7a36e6033bd176e94534b949db0b0e0b","commits":[{"sha":"3f1aea3062937f26134bae46688157292ce6ec41","author":{"email":"43147301+SHyeon614@users.noreply.github.com","name":"SHIN SEUNGHYEON"},"message":"Delete Assignment.md","distinct":true,"url":"https://api.github.com/repos/SHyeon614/Golang-practice/commits/3f1aea3062937f26134bae46688157292ce6ec41"}]},"public":true,"created_at":"2020-06-14T13:58:23Z"},{"id":"12625854334","type":"PushEvent","actor":{"id":335495,"login":"yann-yinn","display_login":"yann-yinn","gravatar_id":"","url":"https://api.github.com/users/yann-yinn","avatar_url":"https://avatars.githubusercontent.com/u/335495?"},"repo":{"id":249501726,"name":"fireblogcms/eleventy-starter-fireblog","url":"https://api.github.com/repos/fireblogcms/eleventy-starter-fireblog"},"payload":{"push_id":5226766238,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"d49a7645692bc3f659540a2b223ea41f6ea0fdf7","before":"3d75ae3a77041c17f52c374d9d7d5922c3fc52a2","commits":[{"sha":"d49a7645692bc3f659540a2b223ea41f6ea0fdf7","author":{"email":"yann.boisselier@gmail.com","name":"yann"},"message":"update install","distinct":true,"url":"https://api.github.com/repos/fireblogcms/eleventy-starter-fireblog/commits/d49a7645692bc3f659540a2b223ea41f6ea0fdf7"}]},"public":true,"created_at":"2020-06-14T13:58:23Z","org":{"id":56117968,"login":"fireblogcms","gravatar_id":"","url":"https://api.github.com/orgs/fireblogcms","avatar_url":"https://avatars.githubusercontent.com/u/56117968?"}},{"id":"12625854331","type":"PushEvent","actor":{"id":981514,"login":"goatshriek","display_login":"goatshriek","gravatar_id":"","url":"https://api.github.com/users/goatshriek","avatar_url":"https://avatars.githubusercontent.com/u/981514?"},"repo":{"id":20359440,"name":"goatshriek/stumpless","url":"https://api.github.com/repos/goatshriek/stumpless"},"payload":{"push_id":5226766235,"size":2,"distinct_size":2,"ref":"refs/heads/entry-revamp","head":"e0df1132605bbc1ee4df549b56aca2eb55aa4555","before":"82813405248e0a935485574b39f87f02e85aed6c","commits":[{"sha":"da0045f99d36d8d45eaf54031c4bf745f13e281c","author":{"email":"joelanderson333@gmail.com","name":"Joel Anderson"},"message":"add c++ binding for get_param_by_index","distinct":true,"url":"https://api.github.com/repos/goatshriek/stumpless/commits/da0045f99d36d8d45eaf54031c4bf745f13e281c"},{"sha":"e0df1132605bbc1ee4df549b56aca2eb55aa4555","author":{"email":"joelanderson333@gmail.com","name":"Joel Anderson"},"message":"add more functions","distinct":true,"url":"https://api.github.com/repos/goatshriek/stumpless/commits/e0df1132605bbc1ee4df549b56aca2eb55aa4555"}]},"public":true,"created_at":"2020-06-14T13:58:23Z"},{"id":"12625854325","type":"ForkEvent","actor":{"id":49107425,"login":"omdbsd","display_login":"omdbsd","gravatar_id":"","url":"https://api.github.com/users/omdbsd","avatar_url":"https://avatars.githubusercontent.com/u/49107425?"},"repo":{"id":33041711,"name":"ryanhanwu/How-To-Ask-Questions-The-Smart-Way","url":"https://api.github.com/repos/ryanhanwu/How-To-Ask-Questions-The-Smart-Way"},"payload":{"forkee":{"id":272212868,"node_id":"MDEwOlJlcG9zaXRvcnkyNzIyMTI4Njg=","name":"How-To-Ask-Questions-The-Smart-Way","full_name":"omdbsd/How-To-Ask-Questions-The-Smart-Way","private":false,"owner":{"login":"omdbsd","id":49107425,"node_id":"MDQ6VXNlcjQ5MTA3NDI1","avatar_url":"https://avatars1.githubusercontent.com/u/49107425?v=4","gravatar_id":"","url":"https://api.github.com/users/omdbsd","html_url":"https://github.c ...

# %%
print(r.json())
# Out:
# [{'id': '12625854335', 'type': 'PushEvent', 'actor': {'id': 43147301, 'login': 'SHyeon614', 'display_login': 'SHyeon614', 'gravatar_id': '', 'url': 'https://api.github.com/users/SHyeon614', 'avatar_url': 'https://avatars.githubusercontent.com/u/43147301?'}, 'repo': {'id': 262723077, 'name': 'SHyeon614/Golang-practice', 'url': 'https://api.github.com/repos/SHyeon614/Golang-practice'}, 'payload': {'push_id': 5226766242, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/master', 'head': '3f1aea3062937f26134bae46688157292ce6ec41', 'before': '993edcee7a36e6033bd176e94534b949db0b0e0b', 'commits': [{'sha': '3f1aea3062937f26134bae46688157292ce6ec41', 'author': {'email': '43147301+SHyeon614@users.noreply.github.com', 'name': 'SHIN SEUNGHYEON'}, 'message': 'Delete Assignment.md', 'distinct': True, 'url': 'https://api.github.com/repos/SHyeon614/Golang-practice/commits/3f1aea3062937f26134bae46688157292ce6ec41'}]}, 'public': True, 'created_at': '2020-06-14T13:58:23Z'}, {'id': '12625854334', 'type': 'PushEvent', 'actor': {'id': 335495, 'login': 'yann-yinn', 'display_login': 'yann-yinn', 'gravatar_id': '', 'url': 'https://api.github.com/users/yann-yinn', 'avatar_url': 'https://avatars.githubusercontent.com/u/335495?'}, 'repo': {'id': 249501726, 'name': 'fireblogcms/eleventy-starter-fireblog', 'url': 'https://api.github.com/repos/fireblogcms/eleventy-starter-fireblog'}, 'payload': {'push_id': 5226766238, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/master', 'head': 'd49a7645692bc3f659540a2b223ea41f6ea0fdf7', 'before': '3d75ae3a77041c17f52c374d9d7d5922c3fc52a2', 'commits': [{'sha': 'd49a7645692bc3f659540a2b223ea41f6ea0fdf7', 'author': {'email': 'yann.boisselier@gmail.com', 'name': 'yann'}, 'message': 'update install', 'distinct': True, 'url': 'https://api.github.com/repos/fireblogcms/eleventy-starter-fireblog/commits/d49a7645692bc3f659540a2b223ea41f6ea0fdf7'}]}, 'public': True, 'created_at': '2020-06-14T13:58:23Z', 'org': {'id': 56117968, 'login': 'fireblogcms', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/fireblogcms', 'avatar_url': 'https://avatars.githubusercontent.com/u/56117968?'}}, {'id': '12625854331', 'type': 'PushEvent', 'actor': {'id': 981514, 'login': 'goatshriek', 'display_login': 'goatshriek', 'gravatar_id': '', 'url': 'https://api.github.com/users/goatshriek', 'avatar_url': 'https://avatars.githubusercontent.com/u/981514?'}, 'repo': {'id': 20359440, 'name': 'goatshriek/stumpless', 'url': 'https://api.github.com/repos/goatshriek/stumpless'}, 'payload': {'push_id': 5226766235, 'size': 2, 'distinct_size': 2, 'ref': 'refs/heads/entry-revamp', 'head': 'e0df1132605bbc1ee4df549b56aca2eb55aa4555', 'before': '82813405248e0a935485574b39f87f02e85aed6c', 'commits': [{'sha': 'da0045f99d36d8d45eaf54031c4bf745f13e281c', 'author': {'email': 'joelanderson333@gmail.com', 'name': 'Joel Anderson'}, 'message': 'add c++ binding for get_param_by_index', 'distinct': True, 'url': 'https://api.github.com/repos/goatshriek/stumpless/commits/da0045f99d36d8d45eaf54031c4bf745f13e281c'}, {'sha': 'e0df1132605bbc1ee4df549b56aca2eb55aa4555', 'author': {'email': 'joelanderson333@gmail.com', 'name': 'Joel Anderson'}, 'message': 'add more functions', 'distinct': True, 'url': 'https://api.github.com/repos/goatshriek/stumpless/commits/e0df1132605bbc1ee4df549b56aca2eb55aa4555'}]}, 'public': True, 'created_at': '2020-06-14T13:58:23Z'}, {'id': '12625854325', 'type': 'ForkEvent', 'actor': {'id': 49107425, 'login': 'omdbsd', 'display_login': 'omdbsd', 'gravatar_id': '', 'url': 'https://api.github.com/users/omdbsd', 'avatar_url': 'https://avatars.githubusercontent.com/u/49107425?'}, 'repo': {'id': 33041711, 'name': 'ryanhanwu/How-To-Ask-Questions-The-Smart-Way', 'url': 'https://api.github.com/repos/ryanhanwu/How-To-Ask-Questions-The-Smart-Way'}, 'payload': {'forkee': {'id': 272212868, 'node_id': 'MDEwOlJlcG9zaXRvcnkyNzIyMTI4Njg=', 'name': 'How-To-Ask-Questions-The-Smart-Way', 'full_name': 'omdbsd/How-To-Ask-Questions-The-Smart-Way', 'private': False, 'owner':  ...

# %%
# convert to string and display well
str_content = r.content.decode("utf-8")
str_content
# Out:
# '[{"id":"12625854335","type":"PushEvent","actor":{"id":43147301,"login":"SHyeon614","display_login":"SHyeon614","gravatar_id":"","url":"https://api.github.com/users/SHyeon614","avatar_url":"https://avatars.githubusercontent.com/u/43147301?"},"repo":{"id":262723077,"name":"SHyeon614/Golang-practice","url":"https://api.github.com/repos/SHyeon614/Golang-practice"},"payload":{"push_id":5226766242,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"3f1aea3062937f26134bae46688157292ce6ec41","before":"993edcee7a36e6033bd176e94534b949db0b0e0b","commits":[{"sha":"3f1aea3062937f26134bae46688157292ce6ec41","author":{"email":"43147301+SHyeon614@users.noreply.github.com","name":"SHIN SEUNGHYEON"},"message":"Delete Assignment.md","distinct":true,"url":"https://api.github.com/repos/SHyeon614/Golang-practice/commits/3f1aea3062937f26134bae46688157292ce6ec41"}]},"public":true,"created_at":"2020-06-14T13:58:23Z"},{"id":"12625854334","type":"PushEvent","actor":{"id":335495,"login":"yann-yinn","display_login":"yann-yinn","gravatar_id":"","url":"https://api.github.com/users/yann-yinn","avatar_url":"https://avatars.githubusercontent.com/u/335495?"},"repo":{"id":249501726,"name":"fireblogcms/eleventy-starter-fireblog","url":"https://api.github.com/repos/fireblogcms/eleventy-starter-fireblog"},"payload":{"push_id":5226766238,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"d49a7645692bc3f659540a2b223ea41f6ea0fdf7","before":"3d75ae3a77041c17f52c374d9d7d5922c3fc52a2","commits":[{"sha":"d49a7645692bc3f659540a2b223ea41f6ea0fdf7","author":{"email":"yann.boisselier@gmail.com","name":"yann"},"message":"update install","distinct":true,"url":"https://api.github.com/repos/fireblogcms/eleventy-starter-fireblog/commits/d49a7645692bc3f659540a2b223ea41f6ea0fdf7"}]},"public":true,"created_at":"2020-06-14T13:58:23Z","org":{"id":56117968,"login":"fireblogcms","gravatar_id":"","url":"https://api.github.com/orgs/fireblogcms","avatar_url":"https://avatars.githubusercontent.com/u/56117968?"}},{"id":"12625854331","type":"PushEvent","actor":{"id":981514,"login":"goatshriek","display_login":"goatshriek","gravatar_id":"","url":"https://api.github.com/users/goatshriek","avatar_url":"https://avatars.githubusercontent.com/u/981514?"},"repo":{"id":20359440,"name":"goatshriek/stumpless","url":"https://api.github.com/repos/goatshriek/stumpless"},"payload":{"push_id":5226766235,"size":2,"distinct_size":2,"ref":"refs/heads/entry-revamp","head":"e0df1132605bbc1ee4df549b56aca2eb55aa4555","before":"82813405248e0a935485574b39f87f02e85aed6c","commits":[{"sha":"da0045f99d36d8d45eaf54031c4bf745f13e281c","author":{"email":"joelanderson333@gmail.com","name":"Joel Anderson"},"message":"add c++ binding for get_param_by_index","distinct":true,"url":"https://api.github.com/repos/goatshriek/stumpless/commits/da0045f99d36d8d45eaf54031c4bf745f13e281c"},{"sha":"e0df1132605bbc1ee4df549b56aca2eb55aa4555","author":{"email":"joelanderson333@gmail.com","name":"Joel Anderson"},"message":"add more functions","distinct":true,"url":"https://api.github.com/repos/goatshriek/stumpless/commits/e0df1132605bbc1ee4df549b56aca2eb55aa4555"}]},"public":true,"created_at":"2020-06-14T13:58:23Z"},{"id":"12625854325","type":"ForkEvent","actor":{"id":49107425,"login":"omdbsd","display_login":"omdbsd","gravatar_id":"","url":"https://api.github.com/users/omdbsd","avatar_url":"https://avatars.githubusercontent.com/u/49107425?"},"repo":{"id":33041711,"name":"ryanhanwu/How-To-Ask-Questions-The-Smart-Way","url":"https://api.github.com/repos/ryanhanwu/How-To-Ask-Questions-The-Smart-Way"},"payload":{"forkee":{"id":272212868,"node_id":"MDEwOlJlcG9zaXRvcnkyNzIyMTI4Njg=","name":"How-To-Ask-Questions-The-Smart-Way","full_name":"omdbsd/How-To-Ask-Questions-The-Smart-Way","private":false,"owner":{"login":"omdbsd","id":49107425,"node_id":"MDQ6VXNlcjQ5MTA3NDI1","avatar_url":"https://avatars1.githubusercontent.com/u/49107425?v=4","gravatar_id":"","url":"https://api.github.com/users/omdbsd","html_url":"https://github.com ...

# %%
# make a post request to the same url
r = requests.post('https://httpbin.org/post', data = {'key':'value'})
print(r)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# ~\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x000002AA3BAA8F08>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='httpbin.org', port=443): Max retries exceeded with url: /post (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000002AA3BAA8F08>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-10-8d8941faaeeb> in <module>
#       1 # make a post request to the same url
# ----> 2 r = requests.post('https://httpbin.org/post', data = {'key':'value'})
#       3 print(r)
#
# ~\Anaconda3\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     114     """
#     115
# --> 116     return request('post', url, data=data, json=json, **kwargs)
#     117
#     118
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='httpbin.org', port=443): Max retries exceeded with url: /post (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000002AA3BAA8F08>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %%
r = requests.head('https://httpbin.org/get')
r
# Out:
# <Response [200]>

# %%
r.content
# Out:
# b''

# %%
# If you’re using GET, OPTIONS, POST, PUT, PATCH or DELETE, you can disable redirection handling with the allow_redirects parameter:
r = requests.get('http://github.com/', allow_redirects=False)

# %%
#If you’re using HEAD, you can enable redirection as well:

r = requests.head('http://github.com/', allow_redirects=True)

# %%
# use time outs, perhaps in seconds so that your program does not hang indefinately, especially in production code
r = requests.get('https://github.com/', timeout=0.001)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     163                 self, "Connection to %s timed out. (connect timeout=%s)" %
# --> 164                 (self.host, self.timeout))
#     165
#
# ConnectTimeoutError: (<urllib3.connection.VerifiedHTTPSConnection object at 0x000002AA3B5FBE48>, 'Connection to github.com timed out. (connect timeout=0.001)')
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='github.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x000002AA3B5FBE48>, 'Connection to github.com timed out. (connect timeout=0.001)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# <ipython-input-29-938cafdb36fc> in <module>
#       1 # use time outs, perhaps in seconds so that your program does not hang indefinately, especially in production code
# ----> 2 r = requests.get('https://github.com/', timeout=0.001)
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     502                 # TODO: Remove this in 3.0.0: see #2811
#     503                 if not isinstance(e.reason, NewConnectionError):
# --> 504                     raise ConnectTimeout(e, request=request)
#     505
#     506             if isinstance(e.reason, ResponseError):
#
# ConnectTimeout: HTTPSConnectionPool(host='github.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x000002AA3B5FBE48>, 'Connection to github.com timed out. (connect timeout=0.001)'))

# %%
requests.get('https://github.com/', timeout=1)
# Out:
# <Response [200]>

# %% [markdown]
# ### My APIs

# %%
main_edpoint = 'https://menopausebackendapi.azurewebsites.net/' 
users_endpoint = 'https://menopausebackendapi.azurewebsites.net/api/User/getall'

# %%
import requests
r = requests.get(users_endpoint)
r
# Out:
# <Response [401]>

# %%
auth_cred = [{'UserName' : 'humphry97@outlook.com'}, {'PasswordHash' : 'Humphry254'}]
    
    
auth_token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....6jHsx6CN_xdbK2bhCDU7OwuZMcm2-yako-2GUCM4aZ0'
hed = {'Authorization': 'Bearer ' + auth_token}

url = 'https://menopausebackendapi.azurewebsites.net/api/User/getall'
response = requests.get(url, headers=hed)
print(response)
print(response.json())
# Out:
# <Response [200]>
# [{'dateOfBirth': None, 'termsAndConditionsChecked': False, 'role': 'Admin', 'isUserSignedIn': False, 'profilePhotoPath': None, 'id': '1', 'userName': 'Isaac', 'normalizedUserName': 'ISAAC', 'email': 'isaaccherutich@gmail.com', 'normalizedEmail': 'ISAACCHERUTICH@GMAIL.COM', 'emailConfirmed': False, 'passwordHash': 'AQAAAAEAACcQAAAAEPkDEOrefTLWb7Ljq3yiizDmTdnoNxWARpi2lZB3IbQ2ncYTKhXMuQ4li9wy3GvZaA==', 'securityStamp': 'Z23IT5WJO4Y27VG3LYJJF77DAECL6ZLB', 'concurrencyStamp': '4f54f879-bd20-49aa-ac31-98fbbd7e8798', 'phoneNumber': None, 'phoneNumberConfirmed': False, 'twoFactorEnabled': False, 'lockoutEnd': None, 'lockoutEnabled': True, 'accessFailedCount': 0}, {'dateOfBirth': None, 'termsAndConditionsChecked': False, 'role': 'Admin', 'isUserSignedIn': False, 'profilePhotoPath': None, 'id': '2', 'userName': 'Clinton', 'normalizedUserName': 'CLINTON', 'email': 'clintonoduor3@gmail.com', 'normalizedEmail': 'CLINTONODUOR3@GMAIL.COM', 'emailConfirmed': False, 'passwordHash': 'AQAAAAEAACcQAAAAEBI5PxI+ybRlIXhTt+/eOCDhVO0khuZnpuod/4OtHlFExrvq1QSyjUw6YEHRY/52CA==', 'securityStamp': 'X2FAL4A6WHRLI3EXLJMGNA5ATWJDGANZ', 'concurrencyStamp': '351785da-a1a6-497a-8607-ace02f4f5c0b', 'phoneNumber': None, 'phoneNumberConfirmed': False, 'twoFactorEnabled': False, 'lockoutEnd': None, 'lockoutEnabled': True, 'accessFailedCount': 0}, {'dateOfBirth': None, 'termsAndConditionsChecked': False, 'role': 'Admin', 'isUserSignedIn': False, 'profilePhotoPath': None, 'id': '3', 'userName': 'Lilian', 'normalizedUserName': 'LILIAN', 'email': 'lilianpatience97@outlook.com', 'normalizedEmail': 'LILIANPATIENCE97@OUTLOOK.COM', 'emailConfirmed': False, 'passwordHash': 'AQAAAAEAACcQAAAAEPIzjwpnTmtbQb9i4C2wB//uN2uZlZEerKys9P0so3InGUbCdT76b0Kw8x0O91XUMg==', 'securityStamp': 'AWD6EEOE55FDB7EG2FLNWJC3ISBISJG2', 'concurrencyStamp': '54f711ca-c974-49bc-ae35-c2b19dd2ff65', 'phoneNumber': None, 'phoneNumberConfirmed': False, 'twoFactorEnabled': False, 'lockoutEnd': None, 'lockoutEnabled': True, 'accessFailedCount': 0}, {'dateOfBirth': '1956/August/8', 'termsAndConditionsChecked': True, 'role': 'Doctor', 'isUserSignedIn': True, 'profilePhotoPath': None, 'id': '344e3f2f-0fa8-4023-aa07-eace8a5c2136', 'userName': 'Silvester', 'normalizedUserName': 'SILVESTER', 'email': 'Silvester@gmail.com', 'normalizedEmail': 'SILVESTER@GMAIL.COM', 'emailConfirmed': False, 'passwordHash': 'AQAAAAEAACcQAAAAEL5qTxIq0agROhdfKPB0pkzUAHHqEPmHhPUxVVXaDxVpr98/gNYdAvPhBtcH9rZx2g==', 'securityStamp': 'WNU263YDN4TENUR37DTTQOKGR36LKIAO', 'concurrencyStamp': '910a2faf-eeae-4379-bd01-f87b66293ecf', 'phoneNumber': None, 'phoneNumberConfirmed': False, 'twoFactorEnabled': False, 'lockoutEnd': None, 'lockoutEnabled': True, 'accessFailedCount': 0}, {'dateOfBirth': None, 'termsAndConditionsChecked': False, 'role': 'Admin', 'isUserSignedIn': False, 'profilePhotoPath': None, 'id': '4', 'userName': 'Humphry', 'normalizedUserName': 'HUMPHRY', 'email': 'humphry97@outlook.com', 'normalizedEmail': 'HUMPHRY97@OUTLOOK.COM', 'emailConfirmed': False, 'passwordHash': 'AQAAAAEAACcQAAAAECXgLXYXiyVgfrGpO/IHaAfMn1oHz7mmXqtJEOivN0JhPZ4IES0nTldTvKBmkxCx2w==', 'securityStamp': 'ISA6U3G5J35AQGAYQRPGXHFVYAXZL6Z5', 'concurrencyStamp': '36d4bf32-cc9c-438d-a5e7-8b7282522dc9', 'phoneNumber': None, 'phoneNumberConfirmed': False, 'twoFactorEnabled': False, 'lockoutEnd': None, 'lockoutEnabled': True, 'accessFailedCount': 0}, {'dateOfBirth': 'string', 'termsAndConditionsChecked': True, 'role': 'Other', 'isUserSignedIn': True, 'profilePhotoPath': 'string', 'id': '5', 'userName': 'myemail@outlook.com', 'normalizedUserName': 'MYEMAIL@OUTLOOK.COM', 'email': 'string', 'normalizedEmail': 'STRING', 'emailConfirmed': True, 'passwordHash': 'AQAAAAEAACcQAAAAEAFBdBXysnyAVS9kpj55T8fh/CtgCCdmS3BA0lYkPS5gW/TL+XBS0XbC6omTrzmORQ==', 'securityStamp': 'YNTAWC3YNU3XMP3WTTW3OV3JBZYMJGPU', 'concurrencyStamp': 'a3d8c8d8-9625-4d8a-a3d3-3548fb3145b6', 'phoneNumber': 'string', 'phoneNumberConfirmed': True, 'twoFactorEnabled': False, 'lockoutEnd': '2020-06-03T11:21:03.64 ...

# %%
# now get the authentication key myself
import requests

auth_cred = {"userName": "humphry97@outlook.com",  "password": "Humphry254"}
params = str(auth_cred)
headers = {'Content-type': 'application/json'}
url = "https://menopausebackendapi.azurewebsites.net/api/User/Authenticate"
response = requests.post(url, data = params, headers = headers )
print(response)
print(response.json())
# Out:
# <Response [400]>
# {'type': 'https://tools.ietf.org/html/rfc7231#section-6.5.1', 'title': 'One or more validation errors occurred.', 'status': 400, 'traceId': '|2043ae4a-4118960aef21544f.', 'errors': {'$': ['\'\'\' is an invalid start of a property name. Expected a \'"\'. Path: $ | LineNumber: 0 | BytePositionInLine: 1.']}}

# %%
response.headers
# Out:
# {'Transfer-Encoding': 'chunked', 'Content-Type': 'application/problem+json; charset=utf-8', 'Server': 'Microsoft-IIS/10.0', 'X-Powered-By': 'ASP.NET', 'Set-Cookie': 'ARRAffinity=4fb3ceef2548efb7bbb013eea124c79e61cde63afb6fb631b40e88f4368a23e0;Path=/;HttpOnly;Domain=menopausebackendapi.azurewebsites.net', 'Date': 'Sun, 14 Jun 2020 15:52:05 GMT'}

# %%
# Out:
# {'userName': 'humphry97@outlook.com', 'password': 'Humphry254'}
# str

# %%
client_Id = "humphry97@outlook.com"
client_Secret = "Humphry254"

payload = {
    'userName': client_Id,
    'password': client_Secret }

url = 'https://menopausebackendapi.azurewebsites.net/api/User/Authenticate/'

r = requests.post(url,
    headers={"Content-Type":"application/json"},
    data={
    'userName': client_Id,
    'password': client_Secret })

# %%
token = json.loads(r.content)
token
# Out:
# {'type': 'https://tools.ietf.org/html/rfc7231#section-6.5.1',
#  'title': 'One or more validation errors occurred.',
#  'status': 400,
#  'traceId': '|2043ae53-4118960aef21544f.',
#  'errors': {'$': ["'u' is an invalid start of a value. Path: $ | LineNumber: 0 | BytePositionInLine: 0."]}}

# %%
print(payload)
# Out:
# {'userName': 'humphry97@outlook.com', 'password': 'Humphry254'}

# %%
# check how to work with cookies to check users location, behavior e.t.c
